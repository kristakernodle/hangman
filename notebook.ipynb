# %%
# !python --version
# !sudo install postgresql
# !pip install psycopg2
# Out:
# Python 3.7.3
# install: missing destination file operand after 'postgresql'
# Try 'install --help' for more information.
# ...
#   Using cached https://files.pythonhosted.org/packages/a8/8f/1c5690eebf148d1d1554fc00ccf9101e134636553dbb75bdfef4f85d7647/psycopg2-2.8.5.tar.gz
#     ERROR: Command errored out with exit status 1:
#      command: /opt/venv/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-8exf2xj2/psycopg2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-8exf2xj2/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-install-8exf2xj2/psycopg2/pip-egg-info
#          cwd: /tmp/pip-install-8exf2xj2/psycopg2/
#     Complete output (23 lines):
#     running egg_info
#     creating /tmp/pip-install-8exf2xj2/psycopg2/pip-egg-info/psycopg2.egg-info
# ...

# %%
# Start writing your code here...
